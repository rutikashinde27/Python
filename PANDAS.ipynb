# %% [markdown]
# <a href="https://colab.research.google.com/github/rutikashinde27/Python/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS

import numpy as np
import pandas as pd

path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv"

df = pd.read_csv(path)

df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
df.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
df[:4]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
#
#   Contract Valid Until    Height  Weight  Release Clause
# ...

# %%
df.tail(3)
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
df[-3:]
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                    Club  Value  Wage Preferred Foot  International Reputation  \
# 18204  Cambridge United   60.0   1.0          Right                       1.0
# 18205   Tranmere Rovers   60.0   1.0          Right                       1.0
# 18206   Tranmere Rovers   60.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 18204          2.0       ST    2017           2021-01-01  5.666667   148.0
# 18205          2.0       RW    2018           2019-01-01  5.833333   154.0
# 18206          2.0       CM    2018           2019-01-01  5.833333   176.0
#
#        Release Clause
# 18204           165.0
# 18205           143.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# ID                          0.000000
# Name                        0.000000
# Age                         0.000000
# Nationality                 0.000000
# Overall                     0.000000
# Potential                   0.000000
# Club                        1.323667
# Value                       1.384083
# Wage                        0.000000
# Preferred Foot              0.000000
# International Reputation    0.263635
# Skill Moves                 0.263635
# Position                    0.000000
# Joined                      0.000000
# Contract Valid Until        1.587302
# Height                      0.000000
# Weight                      0.000000
# Release Clause              0.000000
# dtype: float64

# %%
df.drop(columns=['ID','Name'])
# Out:
#        Age Nationality  Overall  Potential                 Club     Value  \
# 0       31   Argentina       94         94         FC Barcelona  110500.0
# 1       33    Portugal       94         94             Juventus   77000.0
# 2       26      Brazil       92         93  Paris Saint-Germain  118500.0
# 3       27       Spain       91         93    Manchester United   72000.0
# 4       27     Belgium       91         92      Manchester City  102000.0
# ...    ...         ...      ...        ...                  ...       ...
# 18202   19     England       47         65      Crewe Alexandra      60.0
# 18203   19      Sweden       47         63       Trelleborgs FF      60.0
# 18204   16     England       47         67     Cambridge United      60.0
# 18205   17     England       47         66      Tranmere Rovers      60.0
# 18206   16     England       46         66      Tranmere Rovers      60.0
#
#         Wage Preferred Foot  International Reputation  Skill Moves Position  \
# ...

# %%
df.drop(columns=['ID'],inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Preferred Foot', 'International Reputation', 'Skill Moves',
#        'Position', 'Joined', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause'],
#       dtype='object')

# %%
#Part 2 Pandas

# %%
path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv"

df = pd.read_csv(path)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1910/2920738634.py in <cell line: 0>()
#       1 path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv"
#       2
# ----> 3 df = pd.read_csv(path)
#       4
#       5 df
#
# NameError: name 'pd' is not defined

# %%
#PANDAS

import numpy as np
import pandas as pd

path = "https://raw.githubusercontent.com/hakimyameen/Datasets/refs/heads/main/fifa_eda.csv"

df = pd.read_csv(path)

df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
#access single column

df['Nationality']
# Out:
# 0        Argentina
# 1         Portugal
# 2           Brazil
# 3            Spain
# 4          Belgium
#            ...
# 18202      England
# 18203       Sweden
# 18204      England
# 18205      England
# 18206      England
# Name: Nationality, Length: 18207, dtype: object

# %%
#approach 2 using dot operator

df.Age
# Out:
# 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Skill Moves', 'Position', 'Joined', 'Contract Valid Until', 'Height',
#        'Weight', 'Release Clause'],
#       dtype='object')

# %%
#access more than 1 column [[]]

df[['Age','Club']]
# Out:
#        Age                 Club
# 0       31         FC Barcelona
# 1       33             Juventus
# 2       26  Paris Saint-Germain
# 3       27    Manchester United
# 4       27      Manchester City
# ...    ...                  ...
# 18202   19      Crewe Alexandra
# 18203   19       Trelleborgs FF
# 18204   16     Cambridge United
# 18205   17      Tranmere Rovers
# 18206   16      Tranmere Rovers
#
# [18207 rows x 2 columns]

# %%
df[['Age','Club']].head(4)
# Out:
#    Age                 Club
# 0   31         FC Barcelona
# 1   33             Juventus
# 2   26  Paris Saint-Germain
# 3   27    Manchester United

# %%
#to access rows and columns we have 2 more options present in pandas
#loc-label based selection
#stop is inclusive

df.loc[:3,:] #[row,column]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
# 3                       4.0          1.0       GK    2011
#
#   Contract Valid Until    Height  Weight  Release Clause
# ...

# %%
df.loc[:3,'Name':'Overall'] #[row,column]
# Out:
#                 Name  Age Nationality  Overall
# 0           L. Messi   31   Argentina       94
# 1  Cristiano Ronaldo   33    Portugal       94
# 2          Neymar Jr   26      Brazil       92
# 3             De Gea   27       Spain       91

# %%
df.loc[:3,'Club':'Wage'] #[row,column]
# Out:
#                   Club     Value   Wage
# 0         FC Barcelona  110500.0  565.0
# 1             Juventus   77000.0  405.0
# 2  Paris Saint-Germain  118500.0  290.0
# 3    Manchester United   72000.0  260.0

# %%
df.loc[:2,:]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# 2                       5.0          5.0       LW    2017
#
#   Contract Valid Until    Height  Weight  Release Clause
# 0           2021-01-01  5.583333   159.0        226500.0
# 1           2022-01-01  6.166667   183.0        127100.0
# 2           2022-01-01  5.750000   150.0        228100.0

# %%
#Interview Question:
df.loc[:2,['Name','Club','Nationality','Age']]
# Out:
#                 Name                 Club Nationality  Age
# 0           L. Messi         FC Barcelona   Argentina   31
# 1  Cristiano Ronaldo             Juventus    Portugal   33
# 2          Neymar Jr  Paris Saint-Germain      Brazil   26

# %%
#iloc --> index based selection
#stop is exclusive
df.iloc[:2,:]
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club     Value   Wage Preferred Foot  International Reputation  \
# 0  FC Barcelona  110500.0  565.0           Left                       5.0
# 1      Juventus   77000.0  405.0          Right                       5.0
#
#    Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 0          4.0       RF    2004           2021-01-01  5.583333   159.0
# 1          5.0       ST    2018           2022-01-01  6.166667   183.0
#
#    Release Clause
# 0        226500.0
# 1        127100.0

# %%
#Interview Question
#Difference between loc and iloc???

# %%
df.iloc[:2,:3]
# Out:
#        ID               Name  Age
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33

# %%
df.iloc[:2,[10,3,1,5]]
# Out:
#    International Reputation Nationality               Name  Potential
# 0                       5.0   Argentina           L. Messi         94
# 1                       5.0    Portugal  Cristiano Ronaldo         94

# %%
#keep the copy of the original before making the changes
new_df=df.copy()

# %%
df.drop(columns=['Club','ID','Name'])
# Out:
#        Age Nationality  Overall  Potential     Value   Wage Preferred Foot  \
# 0       31   Argentina       94         94  110500.0  565.0           Left
# 1       33    Portugal       94         94   77000.0  405.0          Right
# 2       26      Brazil       92         93  118500.0  290.0          Right
# 3       27       Spain       91         93   72000.0  260.0          Right
# 4       27     Belgium       91         92  102000.0  355.0          Right
# ...    ...         ...      ...        ...       ...    ...            ...
# 18202   19     England       47         65      60.0    1.0          Right
# 18203   19      Sweden       47         63      60.0    1.0          Right
# 18204   16     England       47         67      60.0    1.0          Right
# 18205   17     England       47         66      60.0    1.0          Right
# 18206   16     England       46         66      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# ...

# %%
#check duplicate records count
print(df.duplicated().sum())
# Out:
# 0

# %%
#in this dataset we dont have any duplicate record present
#but if any then we can remove them using drop_duplicates()

df.drop_duplicates()
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
#add a new column in existing dataframe

df['New_Name']='Rutika'
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
#add a new row in existing dataframe

# %%
import numpy as np
import pandas as pd

path = "/content/CO2 Emissions_Canada.csv"

c = pd.read_csv(path)

c
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
c.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
#

# %%
c['Make'].unique()
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
#        'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
#        'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'],
#       dtype=object)

# %%
#select only records of BMW
#c.query('expression)
c.query("Make=='BMW'")
# Out:
#      Make                Model          Vehicle Class  Engine Size(L)  \
# 76    BMW                 320i                COMPACT             2.0
# 77    BMW                 320i                COMPACT             2.0
# 78    BMW          320i xDRIVE                COMPACT             2.0
# 79    BMW          328d xDRIVE                COMPACT             2.0
# 80    BMW  328d xDRIVE TOURING  STATION WAGON - SMALL             2.0
# ...   ...                  ...                    ...             ...
# 6635  BMW         X7 xDrive40i         SUV - STANDARD             3.0
# 6636  BMW         X7 xDrive50i         SUV - STANDARD             4.4
# 6637  BMW              X7 M50i         SUV - STANDARD             4.4
# 6638  BMW         Z4 sDrive30i             TWO-SEATER             2.0
# 6639  BMW              Z4 M40i             TWO-SEATER             3.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# ...

# %%
c.query("Make=='BMW' and Cylinders>6")
# Out:
#      Make                     Model   Vehicle Class  Engine Size(L)  \
# 103   BMW               550i xDRIVE        MID-SIZE             4.4
# 104   BMW  550i xDRIVE GRAN TURISMO       FULL-SIZE             4.4
# 106   BMW     650i xDRIVE CABRIOLET      SUBCOMPACT             4.4
# 107   BMW         650i xDRIVE COUPE         COMPACT             4.4
# 108   BMW    650i xDRIVE GRAN COUPE         COMPACT             4.4
# ...   ...                       ...             ...             ...
# 6631  BMW              X5 xDrive50i  SUV - STANDARD             4.4
# 6632  BMW                   X5 M50i  SUV - STANDARD             4.4
# 6634  BMW                   X6 M50i  SUV - STANDARD             4.4
# 6636  BMW              X7 xDrive50i  SUV - STANDARD             4.4
# 6637  BMW                   X7 M50i  SUV - STANDARD             4.4
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 103           8           A8         Z                              14.4
# ...

# %%
c.query("Make == 'BMW' and `Engine Size(L)`>6")
# Out:
#      Make               Model Vehicle Class  Engine Size(L)  Cylinders  \
# 3436  BMW        M760i xDRIVE     FULL-SIZE             6.6         12
# 4495  BMW        M760i xDRIVE     FULL-SIZE             6.6         12
# 5559  BMW       M760Li xDrive     FULL-SIZE             6.6         12
# 6609  BMW  M760i xDrive Sedan     FULL-SIZE             6.6         12
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 3436          AS8         Z                              17.7
# 4495          AS8         Z                              17.7
# 5559          AS8         Z                              17.7
# 6609          AS8         Z                              17.8
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 3436                             11.9                              15.1
# 4495                             11.9                              15.1
# 5559                             11.9                              15.1
# ...

# %%
c.query("`Vehicle Class`=='SUV - STANDARD' ")
# Out:
#         Make                                   Model   Vehicle Class  \
# 43      AUDI                                      Q7  SUV - STANDARD
# 44      AUDI                       Q7 TDI (modified)  SUV - STANDARD
# 130      BMW                            X5 xDRIVE35i  SUV - STANDARD
# 131      BMW                            X5 xDRIVE50i  SUV - STANDARD
# 132      BMW                                    X6 M  SUV - STANDARD
# ...      ...                                     ...             ...
# 7339  TOYOTA                   Highlander Hybrid AWD  SUV - STANDARD
# 7340  TOYOTA  Highlander Hybrid AWD Limited/Platinum  SUV - STANDARD
# 7348  TOYOTA                             Sequoia 4WD  SUV - STANDARD
# 7383   VOLVO                             XC90 T5 AWD  SUV - STANDARD
# 7384   VOLVO                             XC90 T6 AWD  SUV - STANDARD
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 43               3.0          6          AS8         Z
# ...

# %%
c.query("`Vehicle Class`=='SUV - STANDARD' ")

# %%
#Access/Filter data using Indexing
#Boolean Indexing

c[c['Vehicle Class'] == 'FULL-SIZE']
# Out:
#        Make        Model Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX     FULL-SIZE             2.0          4
# 1     ACURA          ILX     FULL-SIZE             2.4          4
# 2     ACURA   ILX HYBRID     FULL-SIZE             1.5          4
# 3     ACURA      MDX 4WD     FULL-SIZE             3.5          6
# 4     ACURA      RDX AWD     FULL-SIZE             3.5          6
# ...     ...          ...           ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     FULL-SIZE             2.0          4
# 7381  VOLVO  XC60 T5 AWD     FULL-SIZE             2.0          4
# 7382  VOLVO  XC60 T6 AWD     FULL-SIZE             2.0          4
# 7383  VOLVO  XC90 T5 AWD     FULL-SIZE             2.0          4
# 7384  VOLVO  XC90 T6 AWD     FULL-SIZE             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
c[c['Make'] == 'ACURA']
# Out:
#        Make                              Model Vehicle Class  Engine Size(L)  \
# 0     ACURA                                ILX     FULL-SIZE             2.0
# 1     ACURA                                ILX     FULL-SIZE             2.4
# 2     ACURA                         ILX HYBRID     FULL-SIZE             1.5
# 3     ACURA                            MDX 4WD     FULL-SIZE             3.5
# 4     ACURA                            RDX AWD     FULL-SIZE             3.5
# ...     ...                                ...           ...             ...
# 6508  ACURA                     RDX AWD A-SPEC     FULL-SIZE             2.0
# 6509  ACURA                         RLX Hybrid     FULL-SIZE             3.5
# 6510  ACURA                         TLX A-SPEC     FULL-SIZE             2.4
# 6511  ACURA                         TLX SH-AWD     FULL-SIZE             3.5
# 6512  ACURA  TLX SH-AWD A-SPEC/Limited Edition     FULL-SIZE             3.5
#
# ...

# %%
c[:1]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX     FULL-SIZE             2.0          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196

# %%
#use bitwise & operator as we have multiple True False comparison
#logical and wont work here as it is only for single comparison

c[(c['Make']=='ACURA') & (c['Cylinders']==6)]
# Out:
#        Make                              Model Vehicle Class  Engine Size(L)  \
# 3     ACURA                            MDX 4WD     FULL-SIZE             3.5
# 4     ACURA                            RDX AWD     FULL-SIZE             3.5
# 5     ACURA                                RLX     FULL-SIZE             3.5
# 6     ACURA                                 TL     FULL-SIZE             3.5
# 7     ACURA                             TL AWD     FULL-SIZE             3.7
# 8     ACURA                             TL AWD     FULL-SIZE             3.7
# 11    ACURA                                TSX     FULL-SIZE             3.5
# 1074  ACURA                         MDX SH-AWD     FULL-SIZE             3.5
# 1075  ACURA                            RDX AWD     FULL-SIZE             3.5
# 1076  ACURA                                RLX     FULL-SIZE             3.5
# 1077  ACURA                         RLX HYBRID     FULL-SIZE             3.5
# ...

# %%
#Groupby operations

# %%
c[:1]
# Out:
#     Make Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA   ILX     FULL-SIZE             2.0          4          AS5
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196

# %%
c.groupby(['Make'])

# %%
list(c.groupby(['Make']))
# Out:
# [(('ACURA',),
#          Make                              Model Vehicle Class  Engine Size(L)  \
#   0     ACURA                                ILX     FULL-SIZE             2.0
#   1     ACURA                                ILX     FULL-SIZE             2.4
#   2     ACURA                         ILX HYBRID     FULL-SIZE             1.5
#   3     ACURA                            MDX 4WD     FULL-SIZE             3.5
#   4     ACURA                            RDX AWD     FULL-SIZE             3.5
#   ...     ...                                ...           ...             ...
#   6508  ACURA                     RDX AWD A-SPEC     FULL-SIZE             2.0
#   6509  ACURA                         RLX Hybrid     FULL-SIZE             3.5
#   6510  ACURA                         TLX A-SPEC     FULL-SIZE             2.4
#   6511  ACURA                         TLX SH-AWD     FULL-SIZE             3.5
#   6512  ACURA  TLX SH-AWD A-SPEC/Limited Edition     FULL-SIZE             3.5
#
# ...

# %%
#fetch a particular group

c.groupby(['Make']).get_group('TOYOTA')
# Out:
# /tmp/ipykernel_444/2322484765.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   c.groupby(['Make']).get_group('TOYOTA')
#         Make                              Model Vehicle Class  Engine Size(L)  \
# 970   TOYOTA            4RUNNER (Part-Time 4WD)     FULL-SIZE             4.0
# 971   TOYOTA                        4RUNNER 4WD     FULL-SIZE             4.0
# 972   TOYOTA                             AVALON     FULL-SIZE             3.5
# 973   TOYOTA                              CAMRY     FULL-SIZE             2.5
# 974   TOYOTA                              CAMRY     FULL-SIZE             3.5
# ...      ...                                ...           ...             ...
# 7355  TOYOTA  Tacoma 4WD D-Cab TRD Off-Road/Pro     FULL-SIZE             3.5
# ...
